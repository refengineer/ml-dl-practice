# %% [markdown]
# # 실습| 텐서플로에서 실행하는 선형 회귀

# %%
import numpy as np
import matplotlib.pyplot as plt

# 텐서플로의 케라스 API에서 필요한 함수들을 불러온다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

model = Sequential() # 딥러닝의 한 층 한 층을 add()라는 함수를 사용해 간단히 추가시켜 준다.

# 출력 값, 입력 변수, 분석 방법에 맞게끔 모델을 설정한다.
model.add(Dense(1, input_dim=1, activation='linear')) # model.add()를 통해 내부의 층을 만들 수 있다.

# 오차 수정을 위해 경사 하강법(sgd)을, 오차의 정도를 판단하기 위해
# 평균 제곱 오차(mse)를 사용한다.
model.compile(optimizer='sgd', loss='mse') # model.compile()은 만든 model의 설정을 그대로 실행하라는 의미이다.

# 오차를 최소화하는 과정을 2000번 반복한다.
model.fit(x, y, epochs=2000) # model.fit()은 딥러닝의 기본 방식은 층들이 한 번만 통과하는 것이 아니라 위아래로 여러 차례를 오가며
                            # 최적의 모델을 찾는 것이다. 그리고 한 번 오갈 때 몇 개의 데이터를 사용할 것인지 정하는 함수이다.

plt.scatter(x, y)
plt.plot(x, model.predict(x), 'r')
plt.show()

# 임의의 시간을 집어넣어 점수를 예측하는 모델을 테스트해 보겠다.
hour = 7
prediction = model.predict([hour])
print("%.f시간을 공부할 경우의 예상 점수는 %.02f점이다." % (hour, prediction))
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 5s 5s/step - loss: 7714.5122
# Epoch 2/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 1967.3408
# Epoch 3/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 1117.8683
# Epoch 4/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 987.7806
# Epoch 5/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 963.3870
# Epoch 6/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 954.5516
# Epoch 7/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 948.0352
# Epoch 8/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 941.8931
# Epoch 9/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 935.8397
# Epoch 10/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 929.8327
# Epoch 11/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 923.8655
# Epoch 12/2000
# ...
