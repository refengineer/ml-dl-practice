# %%
# pandas 라이브러리를 불러온다.
import pandas as pd

# 깃 허브에 준비된 데이터를 가져온다.
# !git clone https://github.com/taehojo/data.git

# 광물 데이터를 불러온다.
df = pd.read_csv('./data/sonar3.csv', header=None)

df.head()
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
# ...

# %%
X = df.iloc[:, 0:60]
y = df.iloc[:, 60]

# %% [markdown]
# 저장된 X 데이터와 y 데이터에서 각각 정해진 비율(%)만큼 학습셋과 테스트셋으로 분리시키는 함수가 사이킷런의 train_test_split() 함수이다.

# %%
from sklearn.model_selection import train_test_split

# 학습셋과 테스트셋를 구분한다.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 모델을 설정한다.
model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델을 컴파일 한다.
model.compile(loss='binary_crossentropy', optimizer='adam',
              metrics=['accuracy'])

# 모델을 실행한다.
model.fit(X_train, y_train, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 15/15 [==============================] - 1s 3ms/step - loss: 0.6922 - accuracy: 0.4552
# Epoch 2/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.5310
# Epoch 3/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6734 - accuracy: 0.5931
# Epoch 4/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6643 - accuracy: 0.6138
# Epoch 5/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6546 - accuracy: 0.6276
# Epoch 6/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6386 - accuracy: 0.6690
# Epoch 7/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6223 - accuracy: 0.6552
# Epoch 8/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6057 - accuracy: 0.6897
# Epoch 9/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5866 - accuracy: 0.7034
# Epoch 10/200
# ...

# %% [markdown]
# test_size는 테스트셋의 비율을 나타낸다. 나누어진 학습셋과 테스트셋은 각각 X_train, X_test, y_train, y_test로 저장된다.
# 만들어진 모델을 테스트셋에 적용하려면 model.evaluate() 함수를 사용한다.

# %%
score = model.evaluate(X_test, y_test)
print('Test accuracy:', score[1]) # score[0]: loss, score[1]: accuracy
# Out:
# 2/2 [==============================] - 0s 24ms/step - loss: 0.7385 - accuracy: 0.8254
# Test accuracy: 0.8253968358039856

# %% [markdown]
# 실습| 초음파 광물 예측하기: 학습셋과 테스트셋 구분

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

import pandas as pd

# 깃허브에 준비된 데이터를 가져온다.
# !git clone https://github.com/taehojo/data.git

# 광물 데이터 불러오기
df = pd.read_csv('./data/sonar3.csv', header=None)

# 음파 관련 속성을 X로, 광물의 종류를 y로 저장한다.
X = df.iloc[:, 0:60]
y = df.iloc[:, 60]

# 학습셋과 테스트셋을 구분한다.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    shuffle=True)

# 모델을 설정한다.
model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델을 컴파일한다.
model.compile(loss='binary_crossentropy', optimizer='adam',
              metrics=['accuracy'])

# 모델을 실행한다.
history = model.fit(X_train, y_train, epochs=200, batch_size=10)

# 모델을 테스트셋에 적용해 정확도를 구한다.
score = model.evaluate(X_test, y_test)
print('Test accuracy:', score[1])
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.
# Epoch 1/200
# 15/15 [==============================] - 1s 3ms/step - loss: 0.6951 - accuracy: 0.4828
# Epoch 2/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6680 - accuracy: 0.5862
# Epoch 3/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6610 - accuracy: 0.6621
# Epoch 4/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6508 - accuracy: 0.6621
# Epoch 5/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6409 - accuracy: 0.6828
# Epoch 6/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6259 - accuracy: 0.6897
# Epoch 7/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6115 - accuracy: 0.7103
# Epoch 8/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5968 - accuracy: 0.7655
# Epoch 9/200
# ...
