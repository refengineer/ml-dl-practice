# %%
# pandas 라이브러리를 불러온다.
import pandas as pd

# 깃허브에 준비된 데이터를 가져온다.
# !git clone https://github.com/taehojo/data.git

# 광물 데이터를 불러온다.
df = pd.read_csv('./data/sonar3.csv', header=None)

df.head()
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 3), reused 20 (delta 2), pack-reused 0
# Receiving objects: 100% (21/21), 460.95 KiB | 1.71 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# ...

# %% [markdown]
# 전체가 61개의 열로 되어 있고, 마지막 열이 광물의 종류를 나타낸다. 일반 암석일 경우 0, 광석일 경우 1로 표시되어 있다. 첫 번째 열부터 60번째 열까지는 음파 주파수의 에너지를 0에서 1사이의 숫자로 표시한다.

# %% [markdown]
# 일반 암석과 광석이 각각 몇 개나 포함되어 있는지 알아본다.

# %%
df[60].value_counts()
# Out:
# 1    111
# 0     97
# Name: 60, dtype: int64

# %% [markdown]
# 광석이 111개, 일반 암석잉 97개, 총 208개의 샘플이 준비되어 있다.

# %%
# 1~60번째 열을 X 변수에 저장하고 광물의 종류는 y로 저장한다.
X = df.iloc[:, 0:60]
y = df.iloc[:, 60]

# %% [markdown]
# 실습| 초음파 광물 예측하기: 데이터 확인과 실행

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 모델을 설정한다.
model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델을 컴파일한다.
model.compile(loss='binary_crossentropy', optimizer='adam',
              metrics=['accuracy'])

# 모델을 실행
history = model.fit(X, y, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 21/21 [==============================] - 1s 2ms/step - loss: 0.6960 - accuracy: 0.5337
# Epoch 2/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6719 - accuracy: 0.6106
# Epoch 3/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6591 - accuracy: 0.6250
# Epoch 4/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6425 - accuracy: 0.6779
# Epoch 5/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6264 - accuracy: 0.6731
# Epoch 6/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6074 - accuracy: 0.7115
# Epoch 7/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5914 - accuracy: 0.7067
# Epoch 8/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5749 - accuracy: 0.7452
# Epoch 9/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5602 - accuracy: 0.7500
# Epoch 10/200
# ...
