# %% [markdown]
# # 실습| 아이리스 품종 예측하기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 깃허브에 준비된 데이터를 가져온다.
# !git clone https://github.com/taehojo/data.git

# 아이리스 데이터를 불러온다.
df = pd.read_csv('./data/iris3.csv')

# 속성을 X, 클래스를 y로 저장한다.
X = df.iloc[:, 0:4]
y = df.iloc[:, 4]

# 원-핫 인코딩 처리한다.
y = pd.get_dummies(y)

# 모델 설정
model = Sequential()
model.add(Dense(12, input_dim=4, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.summary()

# 모델 컴파일
model.compile(loss='categorical_crossentropy', optimizer='adam',
              metrics=['accuracy'])

# 모델 실행
history = model.fit(X, y, epochs=50, batch_size=5)
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 12)                60
#
#  dense_19 (Dense)            (None, 8)                 104
#
#  dense_20 (Dense)            (None, 3)                 27
#
# =================================================================
# Total params: 191 (764.00 Byte)
# Trainable params: 191 (764.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 30/30 [==============================] - 1s 3ms/step - loss: 1.4830 - accuracy: 0.3067
# Epoch 2/50
# 30/30 [==============================] - 0s 3ms/step - loss: 1.1972 - accuracy: 0.2733
# Epoch 3/50
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0696 - accuracy: 0.3667
# Epoch 4/50
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0022 - accuracy: 0.3533
# Epoch 5/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9439 - accuracy: 0.4333
# Epoch 6/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.8888 - accuracy: 0.4867
# Epoch 7/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.8465 - accuracy: 0.8333
# Epoch 8/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.7989 - accuracy: 0.8400
# Epoch 9/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.7665 - accuracy: 0.8867
# Epoch 10/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.7309 - accuracy: 0.7400
# Epoch 11/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.8667
# Epoch 12/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6554 - accuracy: 0.8133
# Epoch 13/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6052 - accuracy: 0.9067
# Epoch 14/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5603 - accuracy: 0.9267
# Epoch 15/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5211 - accuracy: 0.8933
# Epoch 16/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4797 - accuracy: 0.9200
# Epoch 17/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4527 - accuracy: 0.9267
# Epoch 18/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4192 - accuracy: 0.9267
# Epoch 19/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.9533
# Epoch 20/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.9467
# Epoch 21/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3501 - accuracy: 0.9467
# Epoch 22/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.9533
# Epoch 23/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3167 - accuracy: 0.9600
# Epoch 24/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2980 - accuracy: 0.9667
# Epoch 25/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2848 - accuracy: 0.9533
# Epoch 26/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2733 - accuracy: 0.9667
# Epoch 27/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2546 - accuracy: 0.9600
# Epoch 28/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2324 - accuracy: 0.9733
# Epoch 29/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2197 - accuracy: 0.9600
# Epoch 30/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2124 - accuracy: 0.9600
# Epoch 31/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2011 - accuracy: 0.9800
# Epoch 32/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1913 - accuracy: 0.9733
# Epoch 33/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1796 - accuracy: 0.9600
# Epoch 34/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1722 - accuracy: 0.9800
# Epoch 35/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1657 - accuracy: 0.9733
# Epoch 36/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1616 - accuracy: 0.9800
# Epoch 37/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1563 - accuracy: 0.9733
# Epoch 38/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1551 - accuracy: 0.9733
# Epoch 39/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1437 - accuracy: 0.9667
# Epoch 40/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 0.9733
# Epoch 41/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9733
# Epoch 42/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1321 - accuracy: 0.9733
# Epoch 43/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1308 - accuracy: 0.9733
# Epoch 44/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1314 - accuracy: 0.9733
# Epoch 45/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1245 - accuracy: 0.9733
# Epoch 46/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1203 - accuracy: 0.9800
# Epoch 47/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.9733
# Epoch 48/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1276 - accuracy: 0.9600
# Epoch 49/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1155 - accuracy: 0.9733
# Epoch 50/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.9733
