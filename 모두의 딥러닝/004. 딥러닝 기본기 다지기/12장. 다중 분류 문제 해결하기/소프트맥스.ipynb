# %%
import pandas as pd

# 깃허브에 준비된 데이터를 가져온다.
# !git clone https://github.com/taehojo/data.git

# 아이리스 데이터를 불러온다.
df = pd.read_csv('./data/iris3.csv')

df.head()
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 3), reused 20 (delta 2), pack-reused 0
# Receiving objects: 100% (21/21), 460.95 KiB | 5.99 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
X = df.iloc[:, 0:4]
y = df.iloc[:, 4]

# 원-핫 인코딩 처리한다.
y = pd.get_dummies(y)

# %% [markdown]
# 예측해야할 값이 3가지 이므로 출력층의 노드 수는 3개이다.
#
#
#
# 또한, 세 가지의 확률을 모두 구해야 하므로 시그모이드 함수가 아닌 다른 함수가 필요하다. 이때 사용되는 함수가 바로 소프트맥스 함수이다. 소프트맥스 함수는 각 항목당 예측 확률을 0과 1 사이의 값으로 나타내 주는데, 이때 각 샘플당 예측 확률의 총합이 1인 형태로 바꾸어 주게 된다.
# activation란에 'softmax'라고 적어 주는 것으로 소프트맥스 함수를 바로 적용할 수 있다.
#
#
# 이항 분류에서 binary_crossentropy를 썼다면, 다항 분류에서는 categorical_crossentropy를 사용한다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 모델 성정
model = Sequential()
model.add(Dense(12, input_dim=4, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.summary()

# 모델 컴파일
model.compile(loss='categorical_crossentropy', optimizer='adam',
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 12)                60
#
#  dense_2 (Dense)             (None, 8)                 104
#
#  dense_3 (Dense)             (None, 3)                 27
#
# ...
# Total params: 191 (764.00 Byte)
# Trainable params: 191 (764.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
