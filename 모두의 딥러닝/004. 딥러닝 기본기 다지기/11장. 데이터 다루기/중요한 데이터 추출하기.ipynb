# %% [markdown]
# plasma(공복 혈당 농도) 항목과 BMI(체질량 지수)가 우리가 예측하고자 하는 diabetes 항목과 상관관계가 높다는 것을 알 수 있다.

# %%
# 필요한 라이브러리를 불러온다.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 깃허브에 준비된 데이터를 가져온다.
# !git clone https://github.com/taehojo/data.git

# 피마 인디언 당뇨병 데이터셋을 불러온다.

df = pd.read_csv('./data/pima-indians-diabetes3.csv')


X = df.iloc[:, 0:8] # 세부 정보를 X로 지정한다.
y = df.iloc[:, 8]   # 당뇨병 여부를 y로 지정한다.
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %% [markdown]
# plasma를 기준으로 각각 정상과 당뇨 여부가 어떻게 분포되는지 살펴본다.
# 히스토그램을 그려주는 맷플롯립 라이브러리 hist() 함수를 이용한다.

# %% [markdown]
# hist() 함수 안에 x축으로 지정한다. df 안에 plasma 칼럼 중 diabetes 값이 0인 것과 1인것을 구분해 불러온다.
# bins는 x축을 몇 개의 막대로 쪼개어 보여 줄 것인지 정하는 변수이다.
# barstacked 옵션은 여러 데이터가 쌓여있는 형태의 막대바를 생성하는 옵션이다.
# 불러온 데이터의 이름을 각각 normal(정상)과 diabetes(당뇨)로 정한다.

# %%
plt.hist(x=[df.plasma[df.diabetes==0], df.plasma[df.diabetes==1]], bins=30,
         histtype='barstacked', label=['normal', 'diabetes'])

plt.legend()
plt.show()

# %% [markdown]
# plasma 수치가 높아질수록 당뇨인 경우가 많음을 알 수 있다.

# %% [markdown]
# BMI를 기준으로 각각 정상과 당뇨가 어느 정도 비율로 분포하는지 살펴본다.

# %%
plt.hist(x=[df.bmi[df.diabetes==0], df.bmi[df.diabetes==1]], bins=30,
         histtype='barstacked', label=['normal', 'diabetes'])
plt.legend()
plt.show()

# %% [markdown]
# BMI가 높아질 경우 당뇨의 발병률도 함께 증가하는 추세를 볼 수 있다.

# %% [markdown]
# 결과에 미치는 영향이 큰 항목을 발견하는 것이 데이터 전처리 과정 중 하나이다. 이 밖에도 데이터에 빠진 값이 있다면 평균이나 중앙값으로 대체하거나, 흐름에서 크게 벗어나는 이상치를 제거하는 과정 등이 데이터 전치리에 포함될 수 있다.
