# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# MNIST 데이터를 불러온다.
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# 차원 변환 후, 테스트셋과 학습셋으로 나눈다.
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# 컨볼류션 신경망은 입력된 이미지에서 다시 한 번 특징을 추출하기 위해 커널(슬라이딩 윈도)을 도입하는 기법이다.
# 컨볼루션 층을 만들면 입력 데이터가 가진 특징을 대략적으로 추출해서 학습을 진행한다. 케라스에서 컨볼루션 층을 추가하는 함수는 Conv2D() 이다.

# %% [markdown]
# Conv2D()에 입력되는 인자는 다음과 같다.
# - 첫 번째 인자: 커널을 몇 개 적용할지 정한다.
# - kernel_size: 커널의 크기를 정한다.
# - input_shape: 맨 처음 층에는 입력되는 값을 알려줘야한다. input_shape=(행, 열, 색상 또는 흑백) 형식으로 정한다. 입력 이미지가 색상이면 3, 흑백이면 1을 지정한다.
# - activation: 사용할 활성화 함수를 정의한다.

# %%
from tensorflow.keras.layers import Conv2D

# 컨볼루션 신경망의 설계
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(28, 28, 1),
                 activation='relu'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
