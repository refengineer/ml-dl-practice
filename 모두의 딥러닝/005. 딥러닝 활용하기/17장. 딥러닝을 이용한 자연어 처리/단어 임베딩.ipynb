# %% [markdown]
# 공간적 낭비를 해결하기 위해 등장한 것이 단어 임베딩(word embeding)이라는 방법이다. 이는 각 단어 간의 유사도를 계산한다.
# 적절한 크기로 배열을 바꾸어 주기 위해 최적의 유사도를 계산하는 학습 과정을 거친다. 이 과정은 케라스에서 제공하는 Embedding() 함수를 사용한다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding


model = Sequential()
model.add(Embedding(16, 4)) # 입력될 총 단어 수는 16, 임베딩 후 출력되는 벡터 크기는 4 이다.

# %% [markdown]
# Embedding() 함수는 입력과 출력의 크기를 나타내는 두 개의 매개변수가 있어야 한다.
# 그리고 단어를 매번 얼마나 입력할지 추가로 지정할 수 있도록 input_length의 매개변수를 사용할 수 있다.
